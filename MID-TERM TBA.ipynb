# %% [markdown]
#  # MID-TERM

# %% [markdown]
# # 2)Make a detailed notebook containing all the statistical operations and form various kinds of plots depicting the data or the business focused on. (20 points)

# %%
# Import all the necessary packages and libraries
import pandas as pd 
import numpy as np

# %%
import pandas as pd
file = r'C:\Users\User\Downloads\archive (8)\restaurant.csv'
df = pd.read_csv(file)
df.head(20)# prints only first 20 values from the data
# Out:
#    Restaurant_id        City  \
# 0           id_0       Paris
# 1           id_1    Helsinki
# 2           id_2   Edinburgh
# 3           id_3      London
# 4           id_4  Bratislava
# 5           id_5       Paris
# 6           id_6      Lisbon
# 7           id_7    Budapest
# 8           id_8    Helsinki
# 9           id_9   Stockholm
# 10         id_10        Rome
# 11         id_11       Milan
# 12         id_12      Munich
# 13         id_13     Hamburg
# 14         id_14      Prague
# 15         id_15       Paris
# 16         id_16       Milan
# 17         id_17      London
# 18         id_18      Vienna
# 19         id_19      Dublin
#
#                                         Cuisine Style  Ranking Price Range  \
# 0                                      ['Bar', 'Pub']  12963.0    $$ - $$$
# 1   ['European', 'Scandinavian', 'Gluten Free Opti...    106.0    $$ - $$$
# 2                             ['Vegetarian Friendly']    810.0    $$ - $$$
# ...

# %% [markdown]
# # Data Preprocessing

# %%
# Printing the Columns Present in Dataset
print(df.columns)
# Out:
# Index(['Restaurant_id', 'City', 'Cuisine Style', 'Ranking', 'Price Range',
#        'Number of Reviews', 'Reviews', 'URL_TA', 'ID_TA'],
#       dtype='object')

# %% [markdown]
# # Display the data types of each column in a DataFrame

# %%
# Printing the Datatypes Present in Dataset
print(df.dtypes)
# Out:
# Restaurant_id         object
# City                  object
# Cuisine Style         object
# Ranking              float64
# Price Range           object
# Number of Reviews    float64
# Reviews               object
# URL_TA                object
# ID_TA                 object
# dtype: object

# %% [markdown]
# # Provides a concise summary of a DataFrame, including the number of non-null values and data types for each column

# %%
# Printing the Information of Dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Restaurant_id      10000 non-null  object
#  1   City               10000 non-null  object
#  2   Cuisine Style      7693 non-null   object
#  3   Ranking            10000 non-null  float64
#  4   Price Range        6525 non-null   object
#  5   Number of Reviews  9343 non-null   float64
#  6   Reviews            9998 non-null   object
#  7   URL_TA             10000 non-null  object
#  8   ID_TA              10000 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 703.3+ KB
# None

# %% [markdown]
# # Getting descriptive statistics of a DataFrame's numerical columns

# %%
# Printing the Statistical Information for Numerical Cloumns of Dataset
print(df.describe())
# Out:
#             Ranking  Number of Reviews
# count  10000.000000        9343.000000
# mean    3618.023500         123.050840
# std     3665.076451         287.819368
# min        2.000000           2.000000
# 25%      966.000000           9.000000
# 50%     2257.000000          32.000000
# 75%     5137.000000         114.000000
# max    16443.000000        6437.000000

# %%
# Creating New Column named Length, to Store Length of the Text Column
df['Length'] = df['Reviews'].str.len()
df.describe()
# Out:
#             Ranking  Number of Reviews       Length
# count  10000.000000        9343.000000  9998.000000
# mean    3618.023500         123.050840    69.755751
# std     3665.076451         287.819368    33.544751
# min        2.000000           2.000000     8.000000
# 25%      966.000000           9.000000    54.000000
# 50%     2257.000000          32.000000    78.000000
# 75%     5137.000000         114.000000    94.000000
# max    16443.000000        6437.000000   130.000000

# %%
# Using the Describe Method
df.describe(include='O')
# Out:
#        Restaurant_id    City Cuisine Style Price Range   Reviews  \
# count          10000   10000          7693        6525      9998
# unique         10000      31          3128           3      8358
# top             id_0  London   ['Italian']    $$ - $$$  [[], []]
# freq               1    1436           300        4629      1641
#
#                                                    URL_TA      ID_TA
# count                                               10000      10000
# unique                                              10000      10000
# top     /Restaurant_Review-g187147-d10746918-Reviews-L...  d10746918
# freq                                                    1          1

# %% [markdown]
# # Extraction Of Data

# %%
# Finding Null Values in Dataset
df.isna().sum()
# Out:
# Restaurant_id           0
# City                    0
# Cuisine Style        2307
# Ranking                 0
# Price Range          3475
# Number of Reviews     657
# Reviews                 2
# URL_TA                  0
# ID_TA                   0
# Length                  2
# dtype: int64

# %%
# Filling NA values in Speaker and Position Column with Unknown
df['Cuisine Style'].fillna('unknown', inplace=True)
df['Ranking'].fillna('unknown', inplace=True)
df['City'].fillna('unknown', inplace=True)
df['Price Range'].fillna('unknown', inplace=True)
df['Reviews'].fillna('unknown', inplace=True)
df['Number of Reviews'].fillna('unknown', inplace=True)
df['Length'].fillna('unknown', inplace=True)
df.isna().sum()
# Out:
# Restaurant_id        0
# City                 0
# Cuisine Style        0
# Ranking              0
# Price Range          0
# Number of Reviews    0
# Reviews              0
# URL_TA               0
# ID_TA                0
# Length               0
# dtype: int64

# %%
# Converting necessary text columns into Uppercase
df['Restaurant_id'] = df['Restaurant_id'].str.upper()
df['City'] = df['City'].str.upper()
df['Cuisine Style'] = df['Cuisine Style'].str.upper()
df['Reviews'] = df['Reviews'].str.upper()
df.head()
# Out:
#   Restaurant_id        City  \
# 0          ID_0       PARIS
# 1          ID_1    HELSINKI
# 2          ID_2   EDINBURGH
# 3          ID_3      LONDON
# 4          ID_4  BRATISLAVA
#
#                                        Cuisine Style  Ranking Price Range  \
# 0                                     ['BAR', 'PUB']  12963.0    $$ - $$$
# 1  ['EUROPEAN', 'SCANDINAVIAN', 'GLUTEN FREE OPTI...    106.0    $$ - $$$
# 2                            ['VEGETARIAN FRIENDLY']    810.0    $$ - $$$
# 3  ['ITALIAN', 'MEDITERRANEAN', 'EUROPEAN', 'VEGE...   1669.0        $$$$
# 4  ['ITALIAN', 'MEDITERRANEAN', 'EUROPEAN', 'SEAF...     37.0        $$$$
#
#   Number of Reviews                                            Reviews  \
# 0               4.0                                           [[], []]
# 1              97.0  [['VERY GOOD REVIEWS!', 'FINE DINING IN HAKANI...
# 2              28.0  [['BETTER THAN THE LINKS', 'IVY BLACK'], ['12/...
# ...

# %% [markdown]
# #  2)REGEX OPERATIONS TO CLEAN THE TEXT

# %%
import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'be', 'when', 'needn', 'until', "doesn't", 'hers', 'above', 'below', 'this', 'himself', "couldn't", 'up', 'the', 'she', 'yours', 'to', "hasn't", 'was', 'because', 'our', 'those', 'and', 'shouldn', 'during', 'ma', 'he', 'off', 'doing', 'myself', 'too', 'ourselves', "mustn't", 'wasn', 'not', "weren't", 'yourself', 'under', 'who', 'all', 'most', 'same', 'about', 'isn', "needn't", 'wouldn', 'how', 'theirs', 'does', 'in', 'that', 'didn', 'should', 'whom', "you've", 'of', 'why', 'through', 'has', 'while', 'having', 'again', 'his', "she's", "you'll", 'some', 'd', 'out', 'm', 'yourselves', 'being', 'before', 'just', 'won', 'or', 'there', 'further', 'at', 'both', "you're", 'each', 'for', 'your', 'can', 'will', 'their', 'into', 've', 'such', "haven't", 'here', 'over', 'are', 'after', 'on', 'if', 'themselves', 'so', 'doesn', 'weren', 'own', 'my', 'an', 'what', 'shan', 'than', 'i', 'did', 'between', "shan't", 'had', 'were', 'no', "isn't", 'now', 'hadn', 'but', 'then', 'we', 'as', 'couldn', 'the
# ...

# %%
# Importing regex library
import re

# REGEX to remove "/" "," "'"
pattern = r'[\[\],\']'
# Apply the regex substitution to the specified column
df['Reviews'] = df['Reviews'].apply(lambda x: re.sub(pattern, '', x))
df['Cuisine Style'] = df['Cuisine Style'].apply(lambda x: re.sub(pattern, '', x))
df['URL_TA'] = df['URL_TA'].apply(lambda x: re.sub(pattern, '', x))

df
# Out:
#      Restaurant_id        City  \
# 0             ID_0       PARIS
# 1             ID_1    HELSINKI
# 2             ID_2   EDINBURGH
# 3             ID_3      LONDON
# 4             ID_4  BRATISLAVA
# ...            ...         ...
# 9995       ID_9995      LONDON
# 9996       ID_9996      LISBON
# 9997       ID_9997       MILAN
# 9998       ID_9998       MILAN
# 9999       ID_9999       PARIS
#
#                                           Cuisine Style  Ranking Price Range  \
# 0                                               BAR PUB  12963.0    $$ - $$$
# 1     EUROPEAN SCANDINAVIAN GLUTEN FREE OPTIONS VEGE...    106.0    $$ - $$$
# 2                                   VEGETARIAN FRIENDLY    810.0    $$ - $$$
# 3     ITALIAN MEDITERRANEAN EUROPEAN VEGETARIAN FRIE...   1669.0        $$$$
# 4     ITALIAN MEDITERRANEAN EUROPEAN SEAFOOD VEGETAR...     37.0        $$$$
# ...                                                 ...      ...         ...
# ...

# %% [markdown]
# # Data Visualisation and plots

# %%
# Converting ranking column to numerical
df['Length'] = pd.to_numeric(df['Length'], errors='coerce')

# %%
# Importing matplotlib Package
import matplotlib.pyplot as plt

# Taking 'length' as Target Column
df['Length'].plot(label='Length')
plt.xlabel('Index')
plt.ylabel('Length')
# Adding legends
plt.legend()

# Display the plot
plt.show()

# %%
# Converting ranking column to numerical
df['Ranking'] = pd.to_numeric(df['Ranking'], errors='coerce')

# %%
# Importing matplotlib Package
import matplotlib.pyplot as plt

# Taking 'Ranking' as Target Column
plt.scatter(df.index, df['Ranking'], label='Ranking')

# Setting labels for the axes
plt.xlabel('Index')
plt.ylabel('Ranking')

# Adding legend
plt.legend()

# Display the scatter plot
plt.show()

# %%
# Ploting a Box Plot
df['Length'].plot(kind='box', vert=False)

# Adding x and y axis labels
plt.xlabel('Length')
plt.ylabel('')

# Display the plot
plt.show()

# %%
# Drawing a Histogram
df['Ranking'].plot(kind='hist', bins=30)

# Adding x and y axis labels, legend 
plt.xlabel('Ranking')
plt.ylabel('Frequency')
plt.legend()
# Display the plot
plt.show()

# %%
# Drawing a Histogram for charges column
df['Ranking'].plot(kind='hist', bins=30)

# Adding x and y axis labels, legend 
plt.xlabel('Ranking')
plt.ylabel('Frequency')
plt.legend()
# Display the plot
plt.show()

# %%
# Returning all the unique values in City column 
unique_values = df['City'].unique()
unique_values
# Out:
# array(['PARIS', 'HELSINKI', 'EDINBURGH', 'LONDON', 'BRATISLAVA', 'LISBON',
#        'BUDAPEST', 'STOCKHOLM', 'ROME', 'MILAN', 'MUNICH', 'HAMBURG',
#        'PRAGUE', 'VIENNA', 'DUBLIN', 'BARCELONA', 'BRUSSELS', 'MADRID',
#        'OSLO', 'AMSTERDAM', 'BERLIN', 'LYON', 'ATHENS', 'WARSAW',
#        'OPORTO', 'KRAKOW', 'COPENHAGEN', 'LUXEMBOURG', 'ZURICH', 'GENEVA',
#        'LJUBLJANA'], dtype=object)

# %% [markdown]
# # Lets plot between region and charges

# %%
# Importing Seaborn Package
import seaborn as sns
where = df['City'].isin(['AMSTERDAM', 'ATHENS', 'BARCELONA', 'BERLIN', 'BRATISLAVA'])
g = sns.catplot(data=df[where], x="City", y="Ranking", kind='box') # ploting box plot
g.fig.set_size_inches(8, 5) # sixe of plot
# Adding x and y axis labels
plt.xlabel('City') 
plt.ylabel('Ranking')
# Out:
# C:\Users\User\anaconda3\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# Text(-3.9305555555555554, 0.5, 'Ranking')

# %% [markdown]
# # 3) Create pipeline, remove stop words, word frequency analysis and word clouds

# %% [markdown]
# # Pre-processing Pipeline

# %%
# Importing Regex Package
import regex as re
# Defining a Function to Pull Words
def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
# Importing nltk Package
import nltk

# %%
# Downloading all List of Stop Words
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# Out:
# {'be', 'when', 'needn', 'until', "doesn't", 'hers', 'above', 'below', 'this', 'himself', "couldn't", 'up', 'the', 'she', 'yours', 'to', "hasn't", 'was', 'because', 'our', 'those', 'and', 'shouldn', 'during', 'ma', 'he', 'off', 'doing', 'myself', 'too', 'ourselves', "mustn't", 'wasn', 'not', "weren't", 'yourself', 'under', 'who', 'all', 'most', 'same', 'about', 'isn', "needn't", 'wouldn', 'how', 'theirs', 'does', 'in', 'that', 'didn', 'should', 'whom', "you've", 'of', 'why', 'through', 'has', 'while', 'having', 'again', 'his', "she's", "you'll", 'some', 'd', 'out', 'm', 'yourselves', 'being', 'before', 'just', 'won', 'or', 'there', 'further', 'at', 'both', "you're", 'each', 'for', 'your', 'can', 'will', 'their', 'into', 've', 'such', "haven't", 'here', 'over', 'are', 'after', 'on', 'if', 'themselves', 'so', 'doesn', 'weren', 'own', 'my', 'an', 'what', 'shan', 'than', 'i', 'did', 'between', "shan't", 'had', 'were', 'no', "isn't", 'now', 'hadn', 'but', 'then', 'we', 'as', 'couldn', 'the
# ...

# %%
# Creating a Pipeline
pipeline = [str.lower, tokenize]

# Defining a Function to Run the Pipeline
def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
# Running the Pipeline
df['tokens'] = df['Reviews'].apply(prepare, pipeline=pipeline)

# %%
# Creating a New Column for the Number of Tokens
df['num_tokens'] = df['tokens'].map(len)
df.head()
# Out:
#   Restaurant_id        City  \
# 0          ID_0       PARIS
# 1          ID_1    HELSINKI
# 2          ID_2   EDINBURGH
# 3          ID_3      LONDON
# 4          ID_4  BRATISLAVA
#
#                                        Cuisine Style  Ranking Price Range  \
# 0                                            BAR PUB  12963.0    $$ - $$$
# 1  EUROPEAN SCANDINAVIAN GLUTEN FREE OPTIONS VEGE...    106.0    $$ - $$$
# 2                                VEGETARIAN FRIENDLY    810.0    $$ - $$$
# 3  ITALIAN MEDITERRANEAN EUROPEAN VEGETARIAN FRIE...   1669.0        $$$$
# 4  ITALIAN MEDITERRANEAN EUROPEAN SEAFOOD VEGETAR...     37.0        $$$$
#
#   Number of Reviews                                            Reviews  \
# 0               4.0
# 1              97.0  VERY GOOD REVIEWS! FINE DINING IN HAKANIEMI 12...
# 2              28.0  BETTER THAN THE LINKS IVY BLACK 12/28/2017 12/...
# 3             202.0  MOST EXQUISITE DELICIOUS AND AUTHENTIC 12/06/2...
# ...

# %% [markdown]
# # Word Frequency Analysis

# %%
# Importing a function Counter
from collections import Counter

counter = Counter()
df['tokens'].map(counter.update)
print(counter.most_common(5))
# Out:
# [('food', 2678), ('good', 2408), ('great', 2095), ('and', 1889), ('a', 1599)]

# %%
# Creating a New Data Frame for Frequency Analysis 
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')
freq_df.index.name = 'token'

# %%
# Sorting the freq_df based on Frequency
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(10)
# Out:
#        freq
# token
# food   2678
# good   2408
# great  2095
# and    1889
# a      1599
# in     1272
# the    1236
# nice   1124
# place   985
# for     936

# %%
# Printing the Statistical Data of Frequency
freq_df.describe()
# Out:
#               freq
# count  5976.000000
# mean     10.362115
# std      78.744974
# min       1.000000
# 25%       1.000000
# 50%       1.000000
# 75%       3.000000
# max    2678.000000

# %%
# Plotting a bar graph for most frequent words 
ax = freq_df.head(15).plot(kind='bar', width=0.95, figsize=(10,6))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
df.head()
# Out:
#   Restaurant_id        City  \
# 0          ID_0       PARIS
# 1          ID_1    HELSINKI
# 2          ID_2   EDINBURGH
# 3          ID_3      LONDON
# 4          ID_4  BRATISLAVA
#
#                                        Cuisine Style  Ranking Price Range  \
# 0                                            BAR PUB  12963.0    $$ - $$$
# 1  EUROPEAN SCANDINAVIAN GLUTEN FREE OPTIONS VEGE...    106.0    $$ - $$$
# 2                                VEGETARIAN FRIENDLY    810.0    $$ - $$$
# 3  ITALIAN MEDITERRANEAN EUROPEAN VEGETARIAN FRIE...   1669.0        $$$$
# 4  ITALIAN MEDITERRANEAN EUROPEAN SEAFOOD VEGETAR...     37.0        $$$$
#
#   Number of Reviews                                            Reviews  \
# 0               4.0
# 1              97.0  VERY GOOD REVIEWS! FINE DINING IN HAKANIEMI 12...
# 2              28.0  BETTER THAN THE LINKS IVY BLACK 12/28/2017 12/...
# 3             202.0  MOST EXQUISITE DELICIOUS AND AUTHENTIC 12/06/2...
# ...

# %% [markdown]
# # Word Cloud Visualization

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt
wc = WordCloud(background_color='white', width = 300, height=300, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
import numpy as np
def compute_idf(df, column='tokens', preprocess=None, min_df=1):
    def update(doc):
        tokens = doc if preprocess is None else preprocess(doc)
        counter.update(set(tokens))
    # count tokens
    counter = Counter()
    df[column].map(update)
    # create data frame and compute idf
    idf_df = pd.DataFrame.from_dict(counter, orient='index', columns=['df'])
    idf_df = idf_df.query('df >= @min_df')
    idf_df['idf'] = np.log(len(df)/idf_df['df'])+0.1
    idf_df.index.name = 'tokens'
    return idf_df
idf_df = compute_idf(df)

# %%
freq_df['tfidf'] = freq_df['freq'] * idf_df['idf']
freq_df.head()
# Out:
#        freq        tfidf
# token
# food   2678  4109.778298
# good   2408  4023.040987
# great  2095  3761.657581
# and    1889  3491.108941
# a      1599  3267.577326

# %%
wc = WordCloud(background_color='white', width = 300, height=300, margin=2)
wc.fit_words(freq_df['tfidf'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
df['num_tokens'] = df['tokens'].map(len)

def count_keywords(tokens, keywords): 
    tokens = [t for t in tokens if t in keywords]
    counter = Counter(tokens)
    return [counter.get(k, 0) for k in keywords]

# %%
def count_keywords_by(df, by, keywords, column='tokens'):
    
    df = df.reset_index(drop=True) # if the supplied dataframe has gaps in the index
    freq_matrix = df[column].apply(count_keywords, keywords=keywords)
    freq_df = pd.DataFrame.from_records(freq_matrix, columns=keywords)
    freq_df[by] = df[by] # copy the grouping column(s)
    
    return freq_df.groupby(by=by).sum().sort_values(by)

# %%
import seaborn as sns
keywords = ['AMSTERDAM', 'ATHENS', 'BARCELONA', 'BERLIN', 'BRATISLAVA']  
freq_df = count_keywords_by(df, by='City', keywords=keywords)
# compute relative frequencies based on total number of tokens per year
freq_df = freq_df.div(df.groupby('City')['num_tokens'].sum(), axis=0)
# apply square root as sublinear filter for better contrast
freq_df = freq_df.apply(np.sqrt)
plt.figure(figsize=(15, 7)) 
sns.set(font_scale=1) 
sns.heatmap(data=freq_df.T, 
            xticklabels=True, yticklabels=True, cbar=False, cmap="Reds")
sns.set(font_scale=1)

# %% [markdown]
# #  5)Sentiment Analysis

# %%
# Clean the text

# Create a function to clean the tweets
def cleanTxt(text):
    text = re.sub(r'@[A-Za-z0-9]+', '', text) #Remove @mentions replace with blank
    text = re.sub(r'#', '', text) #Remove the '#' symbol, replace with blank
    text = re.sub(r'RT[\s]+', '', text) #Removing RT, replace with blank
    text = re.sub(r'https?:\/\/\S+', '', text) #Remove the hyperlinks
    text = re.sub(r':', '', text) # Remove :
    
    return text

# Cleaning the text
df["Reviews"]= df["Reviews"].apply(cleanTxt)

# Show the clean text
df.head()
# Out:
#   Restaurant_id        City  \
# 0          ID_0       PARIS
# 1          ID_1    HELSINKI
# 2          ID_2   EDINBURGH
# 3          ID_3      LONDON
# 4          ID_4  BRATISLAVA
#
#                                        Cuisine Style  Ranking Price Range  \
# 0                                            BAR PUB  12963.0    $$ - $$$
# 1  EUROPEAN SCANDINAVIAN GLUTEN FREE OPTIONS VEGE...    106.0    $$ - $$$
# 2                                VEGETARIAN FRIENDLY    810.0    $$ - $$$
# 3  ITALIAN MEDITERRANEAN EUROPEAN VEGETARIAN FRIE...   1669.0        $$$$
# 4  ITALIAN MEDITERRANEAN EUROPEAN SEAFOOD VEGETAR...     37.0        $$$$
#
#   Number of Reviews                                            Reviews  \
# 0               4.0
# 1              97.0  VERY GOOD REVIEWS! FINE DINING IN HAKANIEMI 12...
# 2              28.0  BETTER THAN THE LINKS IVY BLACK 12/28/2017 12/...
# 3             202.0  MOST EXQUISITE DELICIOUS AND AUTHENTIC 12/06/2...
# ...

# %%
# Next we have to remove emoji & Unicode from the reddit data.
def remove_emoji(string):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               u"\U00002500-\U00002BEF"  # chinese char
                               u"\U00002702-\U000027B0"
                               u"\U00002702-\U000027B0"
                               u"\U000024C2-\U0001F251"
                               u"\U0001f926-\U0001f937"
                               u"\U00010000-\U0010ffff"
                               u"\u2640-\u2642"
                               u"\u2600-\u2B55"
                               u"\u200d"
                               u"\u23cf"
                               u"\u23e9"
                               u"\u231a"
                               u"\ufe0f"  # dingbats
                               u"\u3030"
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# Cleaning the text
df["Reviews"]= df["Reviews"].apply(remove_emoji)

# Show the clean text
df.head()
# Out:
#   Restaurant_id        City  \
# 0          ID_0       PARIS
# 1          ID_1    HELSINKI
# 2          ID_2   EDINBURGH
# 3          ID_3      LONDON
# 4          ID_4  BRATISLAVA
#
#                                        Cuisine Style  Ranking Price Range  \
# 0                                            BAR PUB  12963.0    $$ - $$$
# 1  EUROPEAN SCANDINAVIAN GLUTEN FREE OPTIONS VEGE...    106.0    $$ - $$$
# 2                                VEGETARIAN FRIENDLY    810.0    $$ - $$$
# 3  ITALIAN MEDITERRANEAN EUROPEAN VEGETARIAN FRIE...   1669.0        $$$$
# 4  ITALIAN MEDITERRANEAN EUROPEAN SEAFOOD VEGETAR...     37.0        $$$$
#
#   Number of Reviews                                            Reviews  \
# 0               4.0
# 1              97.0  VERY GOOD REVIEWS! FINE DINING IN HAKANIEMI 12...
# 2              28.0  BETTER THAN THE LINKS IVY BLACK 12/28/2017 12/...
# 3             202.0  MOST EXQUISITE DELICIOUS AND AUTHENTIC 12/06/2...
# ...

# %% [markdown]
# # Installing TextBlob, which is a Python library for processing textual data

# %%
from textblob import TextBlob
from wordcloud import WordCloud, STOPWORDS

# %%
# Create a function to get the subjectivity
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

# Create a function to get Polarity
def getPolarity(text):
    return TextBlob(text).sentiment.polarity

# Now we create a new column for what we just did and add it to the Tweet_df dataframe
df['Subjectivity'] = df['Reviews'].apply(getSubjectivity)
df['Polarity'] = df['Reviews'].apply(getPolarity)

df.head()
# Out:
#   Restaurant_id        City  \
# 0          ID_0       PARIS
# 1          ID_1    HELSINKI
# 2          ID_2   EDINBURGH
# 3          ID_3      LONDON
# 4          ID_4  BRATISLAVA
#
#                                        Cuisine Style  Ranking Price Range  \
# 0                                            BAR PUB  12963.0    $$ - $$$
# 1  EUROPEAN SCANDINAVIAN GLUTEN FREE OPTIONS VEGE...    106.0    $$ - $$$
# 2                                VEGETARIAN FRIENDLY    810.0    $$ - $$$
# 3  ITALIAN MEDITERRANEAN EUROPEAN VEGETARIAN FRIE...   1669.0        $$$$
# 4  ITALIAN MEDITERRANEAN EUROPEAN SEAFOOD VEGETAR...     37.0        $$$$
#
#   Number of Reviews                                            Reviews  \
# 0               4.0
# 1              97.0  VERY GOOD REVIEWS! FINE DINING IN HAKANIEMI 12...
# 2              28.0  BETTER THAN THE LINKS IVY BLACK 12/28/2017 12/...
# 3             202.0  MOST EXQUISITE DELICIOUS AND AUTHENTIC 12/06/2...
# ...

# %%
# Group the range of Polarity to different categories
def getInsight(score):
    if score < 0:
        return "Negative"
    elif score == 0:
        return "Neutral"
    else:
        return "Positive"
    
df["Insight"] = df["Polarity"].apply(getInsight)

df.head(50)
# Out:
#    Restaurant_id        City  \
# 0           ID_0       PARIS
# 1           ID_1    HELSINKI
# 2           ID_2   EDINBURGH
# 3           ID_3      LONDON
# 4           ID_4  BRATISLAVA
# 5           ID_5       PARIS
# 6           ID_6      LISBON
# 7           ID_7    BUDAPEST
# 8           ID_8    HELSINKI
# 9           ID_9   STOCKHOLM
# 10         ID_10        ROME
# 11         ID_11       MILAN
# 12         ID_12      MUNICH
# 13         ID_13     HAMBURG
# 14         ID_14      PRAGUE
# 15         ID_15       PARIS
# 16         ID_16       MILAN
# 17         ID_17      LONDON
# 18         ID_18      VIENNA
# 19         ID_19      DUBLIN
# 20         ID_20   BARCELONA
# 21         ID_21      LONDON
# 22         ID_22   BARCELONA
# 23         ID_23    BRUSSELS
# 24         ID_24   BARCELONA
# 25         ID_25      MADRID
# 26         ID_26        ROME
# 27         ID_27   BARCELONA
# 28         ID_28   BARCELONA
# 29         ID_29        OSLO
# 30         ID_30      MADRID
# ...

# %%
# Import necessary libraries
import seaborn as sns
import warnings
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')

# %%
# Plot the values count of sentiment
plt.title("Travel Review Sentiment Score")
plt.xlabel("Sentiment")
plt.ylabel("Scores")
plt.rcParams["figure.figsize"] = (10,8)
df["Insight"].value_counts().plot(kind="bar", color="#2078B4")
plt.show()

# %%
text = ' '.join( [twts for twts in df['Reviews']] ) #To join all tweet
    # generate word cloud 
wordcloud = WordCloud(width=1000, height = 600,
                      
                      max_words = 100,
                      stopwords = STOPWORDS,
                      background_color="black").generate(text)

  # Display the generated image:
plt.figure( figsize=(20,10), facecolor='k' )
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off");

# %% [markdown]
# # 4.	Pick 5 random strings which we will encounter in our day-to-day life as a data scientist and write regex to identify them and sort, provide an example and result of the regex for each string.

# %%
import re

text = "Contact: sathwik718@example.com. Event: 2024-04-31. Emergency: (123) 456-7890. Network: 192.168.1.1. Help: https://help.example.com."
patterns = {
    'email': r"[\w\.-]+@[\w\.-]+\.\w+", #This pattern matches email addresses, which typically consist of characters (letters, numbers, underscores, hyphens), followed by an "@" symbol, then more characters, a dot, and finally a domain.
    'date': r"\b\d{4}-\d{2}-\d{2}\b", #This regex matches dates in the ISO format (Year-Month-Day), ensuring that each component (year, month, day) has the correct number of digits.
    'phone': r"\(\d{3}\) \d{3}-\d{4}",# Matches US phone numbers in the format (XXX) XXX-XXXX where X is a digit.
    'IP': r"\b(?:\d{1,3}\.){3}\d{1,3}\b",# Matches IPv4 addresses, which consist of four sets of numbers ranging from 0 to 255, separated by dots. This pattern doesn't check for the validity range (0-255), it only checks the structure.
    'URL': r"\bhttps?:\/\/\S+\b" #This regex matches URLs starting with http or https, followed by any non-whitespace characters. It ensures the URL starts with the protocol and is typically used to extract links from text.
}

for key, pattern in patterns.items():
    match = re.search(pattern, text)
    print(f"{key.title()} found: {match.group()}")
# Out:
# Email found: sathwik718@example.com
# Date found: 2024-04-31
# Phone found: (123) 456-7890
# Ip found: 192.168.1.1
# Url found: https://help.example.com
