# %% [markdown]
# # ASSIGNMENT 2

# %%
import pandas as pd
file = r'C:\Users\User\Downloads\insurance.csv'
df = pd.read_csv(file)
df.head(30)# prints only first 30 values from the data
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# 13   56  female  39.820         0     no  southeast  11090.71780
# 14   27    male  42.130         0    yes  southeast  39611.75770
# 15   19    male  24.600         1     no  southwest   1837.23700
# 16   52  female  30.780         1     no  northeast  10797.33620
# 17   23    male  23.845         0     no  northeast   2395.17155
# 18   56    male  40.300         0     no  southwest  10602.38500
# 19   30    male  35.300         0    yes  southwest  36837.46700
# 20   60  female  36.005         0     no  northeast  13228.84695
# 21   30  female  32.400         1     no  southwest   4149.73600
# 22   18    male  34.100         0     no  southeast   1137.01100
# 23   34  female  31.920         1    yes  northeast  37701.87680
# 24   37    male  28.025         2     no  northwest   6203.90175
# 25   59  female  27.720         3     no  southeast  14001.13380
# 26   63  female  23.085         0     no  northeast  14451.83515
# 27   55  female  32.775         2     no  northwest  12268.63225
# 28   23    male  17.385         1     no  northwest   2775.19215
# 29   31    male  36.300         2    yes  southwest  38711.00000

# %%
df# prints the complete data values
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# # Displaying just a fraction of data

# %%
df.sample(frac=0.2)# It just takes randomly 20% of the data and displays it
# Out:
#       age     sex     bmi  children smoker     region      charges
# 584    19    male  20.700         0     no  southwest   1242.81600
# 18     56    male  40.300         0     no  southwest  10602.38500
# 808    18    male  30.140         0     no  southeast   1131.50660
# 698    56    male  33.725         0     no  northwest  10976.24575
# 1295   20    male  22.000         1     no  southwest   1964.78000
# ...   ...     ...     ...       ...    ...        ...          ...
# 566    38  female  40.565         1     no  northwest   6373.55735
# 815    20  female  31.460         0     no  southeast   1877.92940
# 1331   23  female  33.400         0     no  southwest  10795.93733
# 132    53  female  35.900         2     no  southwest  11163.56800
# 1252   20    male  27.300         0    yes  southwest  16232.84700
#
# [268 rows x 7 columns]

# %%
df.columns# prints only column names
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'region', 'charges'], dtype='object')

# %%
df.dtypes# gives the data type of each column
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
df.info()#gives the complete information about the dataset including null and non null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
df.describe()# gives us a overall values of the given dataset
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
df['length'] = df['region'].str.len()
df.describe()#prints the length of the speech along with the description
# Out:
#                age          bmi     children       charges  length
# count  1338.000000  1338.000000  1338.000000   1338.000000  1338.0
# mean     39.207025    30.663397     1.094918  13270.422265     9.0
# std      14.049960     6.098187     1.205493  12110.011237     0.0
# min      18.000000    15.960000     0.000000   1121.873900     9.0
# 25%      27.000000    26.296250     0.000000   4740.287150     9.0
# 50%      39.000000    30.400000     1.000000   9382.033000     9.0
# 75%      51.000000    34.693750     2.000000  16639.912515     9.0
# max      64.000000    53.130000     5.000000  63770.428010     9.0

# %%
df.describe(include='O')# gives stats about the data
# Out:
#          sex smoker     region
# count   1338   1338       1338
# unique     2      2          4
# top     male     no  southeast
# freq     676   1064        364

# %%
df.isna().sum()# cehcks for the missing data from the total dataset
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# length      0
# dtype: int64

# %% [markdown]
# # Removing null values from the dataset

# %%
df['smoker'].fillna('unkown',inplace=True)
df['bmi'].fillna('unkown',inplace=True)
df.isna().sum()# changes null or NAn values as unknown
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# length      0
# dtype: int64

# %%
df['smoker']=df['smoker'].str.upper()
df['sex']=df['sex'].str.upper()
df['region']=df['region'].str.upper()
df#changes the text in the specified columns into upper cases
# Out:
#       age     sex     bmi  children smoker     region      charges  length
# 0      19  FEMALE  27.900         0    YES  SOUTHWEST  16884.92400       9
# 1      18    MALE  33.770         1     NO  SOUTHEAST   1725.55230       9
# 2      28    MALE  33.000         3     NO  SOUTHEAST   4449.46200       9
# 3      33    MALE  22.705         0     NO  NORTHWEST  21984.47061       9
# 4      32    MALE  28.880         0     NO  NORTHWEST   3866.85520       9
# ...   ...     ...     ...       ...    ...        ...          ...     ...
# 1333   50    MALE  30.970         3     NO  NORTHWEST  10600.54830       9
# 1334   18  FEMALE  31.920         0     NO  NORTHEAST   2205.98080       9
# 1335   18  FEMALE  36.850         0     NO  SOUTHEAST   1629.83350       9
# 1336   21  FEMALE  25.800         0     NO  SOUTHWEST   2007.94500       9
# 1337   61  FEMALE  29.070         0    YES  NORTHWEST  29141.36030       9
#
# [1338 rows x 8 columns]

# %%
df[df['smoker'].str.contains('YES')]
#displays all the smoker with yes
# Out:
#       age     sex     bmi  children smoker     region      charges  length
# 0      19  FEMALE  27.900         0    YES  SOUTHWEST  16884.92400       9
# 11     62  FEMALE  26.290         0    YES  SOUTHEAST  27808.72510       9
# 14     27    MALE  42.130         0    YES  SOUTHEAST  39611.75770       9
# 19     30    MALE  35.300         0    YES  SOUTHWEST  36837.46700       9
# 23     34  FEMALE  31.920         1    YES  NORTHEAST  37701.87680       9
# ...   ...     ...     ...       ...    ...        ...          ...     ...
# 1313   19  FEMALE  34.700         2    YES  SOUTHWEST  36397.57600       9
# 1314   30  FEMALE  23.655         3    YES  NORTHWEST  18765.87545       9
# 1321   62    MALE  26.695         0    YES  NORTHEAST  28101.33305       9
# 1323   42  FEMALE  40.370         2    YES  SOUTHEAST  43896.37630       9
# 1337   61  FEMALE  29.070         0    YES  NORTHWEST  29141.36030       9
#
# [274 rows x 8 columns]

# %% [markdown]
# # A plot for the length column

# %%
df['length'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # BOXPLOT

# %%
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# # HISTOGRAM

# %%
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Box plot for lenth and country columns

# %%
import seaborn as sns 
where = df['region'].isin(['SOUTHWEST', 'SOUTHEAST', 'NORTHEAST', 'NORTHWEST'])
g = sns.catplot(data=df[where], x="region", y="length", kind='box')
g.fig.set_size_inches(10, 8)
# Out:
# C:\Users\User\anaconda3\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # REGEX 2

# %%
import regex as re# imports the regex

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
testtext = "EE saala cup namde 2024! www.dvd.assam"
testtokens = tokenize(testtext)# tokenizes the given sample
 
print(testtokens)
# Out:
# ['EE', 'saala', 'cup', 'namde', 'www', 'dvd', 'assam']

# %% [markdown]
# # STOPWORDS

# %%
import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# imports the inbuilt stopwords depending upon the language specified
# Out:
# {'those', 'ourselves', 'should', 'too', 'how', 'are', 'ours', 'under', 'your', 'when', "shan't", 'of', 'out', 'herself', "needn't", 'be', 'wouldn', 'me', 'nor', 'all', "hasn't", 'needn', 'very', 'weren', 'than', 'm', "aren't", 'over', 'itself', "didn't", "mustn't", 'further', 'before', "won't", 'both', 'you', 'where', "she's", 'hers', 'do', 'them', 'to', 've', 'having', 'only', 'mustn', 'our', 'then', "mightn't", 'hadn', 'same', 'which', 'her', 'it', 'theirs', 'shouldn', 'themselves', 'any', 'other', 'is', 'we', 'here', 'my', 'haven', 'but', 'by', 'didn', "you'd", 'd', 'its', 'they', 'has', 'through', 'y', 'more', 'yours', 'most', 'that', 'can', 'he', "wouldn't", 'now', 'were', 'because', 'as', "doesn't", 'ma', 'some', 'for', "isn't", 'who', 'hasn', 'shan', 'while', "you're", 'why', 'himself', 'she', 'not', "should've", 'such', 'mightn', 'at', 'no', 'off', 'the', 'few', 'each', 'yourself', 't', 're', 'couldn', 'and', 'if', 'will', 'doing', 'there', 'been', 'or', "hadn't", 'doesn', 'am', 'does', 'below', 'i', 'whom', 'had', "that'll", 'being', "you've", 'won', 'between', 'after', 'into', 'up', 'was', 'so', "shouldn't", 'against', 'did', 'once', 'from', 'own', "haven't", 'these', 'above', 'don', 's', 'on', 'o', 'their', 'wasn', 'just', "wasn't", 'what', 'his', 'in', "couldn't", 'll', "weren't", 'aren', 'again', 'a', 'down', 'him', 'until', 'have', "you'll", 'yourselves', 'myself', 'ain', "don't", 'during', 'an', "it's", 'about', 'isn', 'this', 'with'}
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
#removing the stopwords
# Out:
# ['EE', 'saala', 'cup', 'namde', 'www', 'dvd', 'assam']

# %% [markdown]
# # Initialization of the Pipeline

# %%
pipeline = [str.lower, tokenize, remove_stop]

def prepare(region, pipeline):
    tokens = region
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
df['tokens'] = df['region'].apply(prepare, pipeline=pipeline)# runs the pipeline

# %% [markdown]
# # Counting the tokens in the dataset

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       age     sex    bmi  children smoker     region     charges  length  \
# 1333   50    MALE  30.97         3     NO  NORTHWEST  10600.5483       9
# 1334   18  FEMALE  31.92         0     NO  NORTHEAST   2205.9808       9
# 1335   18  FEMALE  36.85         0     NO  SOUTHEAST   1629.8335       9
# 1336   21  FEMALE  25.80         0     NO  SOUTHWEST   2007.9450       9
# 1337   61  FEMALE  29.07         0    YES  NORTHWEST  29141.3603       9
#
#            tokens  num_tokens
# 1333  [northwest]           1
# 1334  [northeast]           1
# 1335  [southeast]           1
# 1336  [southwest]           1
# 1337  [northwest]           1

# %% [markdown]
# # WORD FREQUENCY ANALYSIS
# ## USING THE COUNTER

# %%
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# testing the counter
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
more_tokens = tokenize("She likes dogs and cats.")# adding new data for the already existing count
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
counter = Counter()
df['tokens'].map(counter.update)# using counter on our dataset
print(counter.most_common(5))
# Out:
# [('southeast', 364), ('southwest', 325), ('northwest', 325), ('northeast', 324)]

# %%
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')# specifying the frequency of the word count
freq_df.index.name = 'token'

# %%
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(20)
# sorting the data and displaying it
# Out:
#            freq
# token
# southeast   364
# southwest   325
# northwest   325
# northeast   324

# %%
freq_df.describe()# stats
# Out:
#              freq
# count    4.000000
# mean   334.500000
# std     19.672316
# min    324.000000
# 25%    324.750000
# 50%    325.000000
# 75%    334.750000
# max    364.000000

# %% [markdown]
# # BAR CHART FOR TOKEN AND FREQUENCY¶

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in c:\users\user\anaconda3\anaconda\lib\site-packages (1.9.3)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\anaconda\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\anaconda\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # WORD CLOUD

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

text = df.query("age==18 and region=='NORTHEAST'")['region'].values[0]

plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='white', width = 300, height=300, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
