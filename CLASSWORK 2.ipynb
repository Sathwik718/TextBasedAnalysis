# %% [markdown]
# # Classwork 2 (04/13/2024)

# %%
import pandas as pd
file = r'C:\Users\User\Downloads\un-general-debates-blueprint.csv'
df = pd.read_csv(file)
df.head(30)# prints only first 30 values from the data
# Out:
#     session  year country                     country_name  \
# 0        25  1970     ALB                          Albania
# 1        25  1970     ARG                        Argentina
# 2        25  1970     AUS                        Australia
# 3        25  1970     AUT                          Austria
# 4        25  1970     BEL                          Belgium
# 5        25  1970     BLR                          Belarus
# 6        25  1970     BOL  Bolivia, Plurinational State of
# 7        25  1970     BRA                           Brazil
# 8        25  1970     CAN                           Canada
# 9        25  1970     CMR                         Cameroon
# 10       25  1970     COG                            Congo
# 11       25  1970     COL                         Colombia
# 12       25  1970     CRI                       Costa Rica
# 13       25  1970     CUB                             Cuba
# 14       25  1970     DOM               Dominican Republic
# 15       25  1970     DZA                          Algeria
# 16       25  1970     ECU                          Ecuador
# 17       25  1970     FRA                           France
# 18       25  1970     GBR                   United Kingdom
# 19       25  1970     GHA                            Ghana
# 20       25  1970     GIN                           Guinea
# 21       25  1970     GMB                           Gambia
# 22       25  1970     GTM                        Guatemala
# 23       25  1970     HND                         Honduras
# 24       25  1970     HTI                            Haiti
# 25       25  1970     IDN                        Indonesia
# 26       25  1970     IND                            India
# 27       25  1970     IRN        Iran, Islamic Republic of
# 28       25  1970     IRQ                             Iraq
# 29       25  1970     ISL                          Iceland
#
#                   speaker    position  \
# 0                 Mr. NAS         NaN
# 1      Mr. DE PABLO PARDO         NaN
# 2             Mr. McMAHON         NaN
# 3      Mr. KIRCHSCHLAEGER         NaN
# 4              Mr. HARMEL         NaN
# 5          Mr. GURINOVICH         NaN
# 6      Mr. CAMACHO OMISTE         NaN
# 7      Mr. GIBSON BARBOZA         NaN
# 8               Mr. SHARP         NaN
# 9              Mr. AHIDJO  President
# 10            Mr. ICKONGA         NaN
# 11  Mr. VASQUEZ CARRIZOSA         NaN
# 12              Mr. FACIO         NaN
# 13            Mr. ALARCON         NaN
# 14        Mr FERNANDEZ G.
# 15              Mr. YAZID         NaN
# 16            Mr. Benites         NaN
# 17           Mr. SCHUMANN         NaN
# 18   Sir Alec DOUGLASHOME         NaN
# 19              Mr. OWUSU         NaN
# 20             Mr. CAMARA         NaN
# 21             Mr. JAWARA  President
# 22   Mr. HERRERA IBARGUEN         NaN
# 23    Mr. CARIAS CASTILLO         NaN
# 24           Mr. CHALMERS         NaN
# 25              Mr. MALIK         NaN
# 26       Mr. Swaran SINGH         NaN
# 27             Mr. ZAHEDI         NaN
# 28        Mr. ALSHAIKHLY          NaN
# 29            Mr. JONSSON         NaN
#
#                                                  text
# 0   33: May I first convey to our President the co...
# 1   177.\t : It is a fortunate coincidence that pr...
# 2   100.\t  It is a pleasure for me to extend to y...
# 3   155.\t  May I begin by expressing to Ambassado...
# 4   176. No doubt each of us, before coming up to ...
# 5   \n71.\t. We are today mourning the untimely de...
# 6   135.\t  I wish to congratulate the President o...
# 7   1.\tMr. President, I should like, first of all...
# 8   \nThe General Assembly is fortunate indeed to ...
# 9   : A year ago I came here as the Acting Preside...
# 10  122.\t  I cannot begin my intervention without...
# 11  Mr. President, this visit to the United Nation...
# 12  62.\t  Mr. President, your election to the Pre...
# 13  1.\t  Mr. President, I should first like to co...
# 14  \n\n\n Mr. President, it was a source of great...
# 15  1.  The delegation of Algeria is very pleased ...
# 16  71.  It had been my hope that a loftier person...
# 17  84.\t  Within one month, when we celebrate the...
# 18  110.\t Mr. President, I should like first to s...
# 19  121.\t I should like to begin by congratulatin...
# 20  35.\t  The delegation of the Republic of Guine...
# 21  2.\tPresident : President of Gambia . Mr. Pres...
# 22  196.\t: Before starting my statement may I, by...
# 23  153.\t  This session of the General Assembly w...
# 24  1.\t  Mr. President, I hardly need to emphasiz...
# 25  101.\tOn behalf of the Indonesian delegation, ...
# 26  40.\t Mr. President, I offer you our congratul...
# 27  31.\tMr. President, it is only fitting that on...
# 28  \n133.\tI should like, on behalf of the delega...
# 29   Mr. President, allow me, on behalf of the Ice...

# %%
df# prints the complete data values
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            Mr. NAS
# 1          25  1970     ARG     Argentina                 Mr. DE PABLO PARDO
# 2          25  1970     AUS     Australia                        Mr. McMAHON
# 3          25  1970     AUT       Austria                 Mr. KIRCHSCHLAEGER
# 4          25  1970     BEL       Belgium                         Mr. HARMEL
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  Mr. Abdrabuh Mansour Hadi Mansour
# 7503       70  2015     YUG    Yugoslavia               Mr. Tomislav Nikolić
# 7504       70  2015     ZAF  South Africa                         Jacob Zuma
# 7505       70  2015     ZMB        Zambia             Mr. Edgar Chagwa Lungu
# 7506       70  2015     ZWE      Zimbabwe                      Robert Mugabe
#
#        position                                               text
# 0           NaN  33: May I first convey to our President the co...
# 1           NaN  177.\t : It is a fortunate coincidence that pr...
# 2           NaN  100.\t  It is a pleasure for me to extend to y...
# 3           NaN  155.\t  May I begin by expressing to Ambassado...
# 4           NaN  176. No doubt each of us, before coming up to ...
# ...         ...                                                ...
# 7502  President  On behalf of the people and the Government of ...
# 7503  President  \nSeventy years have passed since the establis...
# 7504  President  I should like to congratulate the President an...
# 7505  President  I would like to begin by thanking the Secretar...
# 7506  President  Allow me at the outset to extend to Mr. Mogens...
#
# [7507 rows x 7 columns]

# %% [markdown]
# # Displaying just a fraction of data

# %%
df.sample(frac=0.2)# It just takes randomly 20% of the data and displays it
# Out:
#       session  year country               country_name  \
# 7011       68  2013     JAM                    Jamaica
# 5297       59  2004     KWT                     Kuwait
# 2043       40  1985     IRN  Iran, Islamic Republic of
# 1730       38  1983     EGY                      Egypt
# 6347       64  2009     ZMB                     Zambia
# ...       ...   ...     ...                        ...
# 5137       58  2003     NGA                    Nigeria
# 5690       61  2006     MEX                     Mexico
# 6638       66  2011     LCA                Saint Lucia
# 6088       63  2008     NER                      Niger
# 3854       51  1996     MNG                   Mongolia
#
#                                       speaker                      position  \
# 7011                    Portia Simpson Miller                Prime Minister
# 5297  Sheikh Mohammad Sabah Al-Salem Al-Sabah  Minister for Foreign Affairs
# 2043                             Mr. Velayati                           NaN
# 1730                                  Mubarak                    President
# 6347                     Rupiah Bwezani Banda                     President
# ...                                       ...                           ...
# 5137                        Olusegun Obasanjo                     President
# 5690                          Mr. Vincete Fox                     President
# 6638                  Donatus Keith St. Aimee             UN Representative
# 6088                      Aichatou Mindaoudou  Minister for Foreign Affairs
# 3854                 Mendsaikhany Enkhsaikhan                Prime Minister
#
#                                                    text
# 7011  I am extremely \npleased that a son of the Car...
# 5297  I am\npleased to convey my congratulations to ...
# 2043  I wish to offer my congratulations to Ambassad...
# 1730  ﻿1.\t It is my pleasure to address, in the nam...
# 6347  Let me join previous speakers \nin congratulat...
# ...                                                 ...
# 5137  ﻿On behalf of the\nGovernment and people of Ni...
# 5690  Twenty-one \nyears ago, on a day like today, a...
# 6638  Not since the \nprelude to the two world wars ...
# 6088  At \nthe outset, Sir, I should like to warmly ...
# 3854  ﻿At the outset, I wish\nto extend my sincere c...
#
# [1501 rows x 7 columns]

# %%
df.columns# prints only column names
# Out:
# Index(['session', 'year', 'country', 'country_name', 'speaker', 'position',
#        'text'],
#       dtype='object')

# %%
df.dtypes# gives the data type of each column
# Out:
# session          int64
# year             int64
# country         object
# country_name    object
# speaker         object
# position        object
# text            object
# dtype: object

# %%
df.info()#gives the complete information about the dataset including null and non null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7507 entries, 0 to 7506
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   session       7507 non-null   int64
#  1   year          7507 non-null   int64
#  2   country       7507 non-null   object
#  3   country_name  7507 non-null   object
#  4   speaker       7480 non-null   object
#  5   position      4502 non-null   object
#  6   text          7507 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 410.7+ KB

# %%
df.describe()# gives us a overall values of the given dataset
# Out:
#            session         year
# count  7507.000000  7507.000000
# mean     49.610763  1994.610763
# std      12.892155    12.892155
# min      25.000000  1970.000000
# 25%      39.000000  1984.000000
# 50%      51.000000  1996.000000
# 75%      61.000000  2006.000000
# max      70.000000  2015.000000

# %%
df['length'] = df['text'].str.len()
df.describe()#prints the length of the speech along with the description
# Out:
#            session         year        length
# count  7507.000000  7507.000000   7507.000000
# mean     49.610763  1994.610763  17967.281604
# std      12.892155    12.892155   7860.038463
# min      25.000000  1970.000000   2362.000000
# 25%      39.000000  1984.000000  12077.000000
# 50%      51.000000  1996.000000  16424.000000
# 75%      61.000000  2006.000000  22479.500000
# max      70.000000  2015.000000  72041.000000

# %%
df.describe(include='O')# gives stats about the data
# Out:
#        country country_name        speaker                      position  \
# count     7507         7507           7480                          4502
# unique     199          199           5428                           113
# top        ALB      Albania  Seyoum Mesfin  Minister for Foreign Affairs
# freq        46           46             12                          1813
#
#                                                      text
# count                                                7507
# unique                                               7507
# top     33: May I first convey to our President the co...
# freq                                                    1

# %%
df.isna().sum()# cehcks for the missing data from the total dataset
# Out:
# session            0
# year               0
# country            0
# country_name       0
# speaker           27
# position        3005
# text               0
# length             0
# dtype: int64

# %% [markdown]
# # Removing null values from the dataset

# %%
df['speaker'].fillna('unkown',inplace=True)
df['position'].fillna('unkown',inplace=True)
df.isna().sum()# changes null or NAn values as unknown
# Out:
# session         0
# year            0
# country         0
# country_name    0
# speaker         0
# position        0
# text            0
# length          0
# dtype: int64

# %%
df['speaker']=df['speaker'].str.lower()
df['position']=df['position'].str.lower()
df['text']=df['text'].str.lower()
df#changes the text in the specified columns into lower cases
# Out:
#       session  year country  country_name                            speaker  \
# 0          25  1970     ALB       Albania                            mr. nas
# 1          25  1970     ARG     Argentina                 mr. de pablo pardo
# 2          25  1970     AUS     Australia                        mr. mcmahon
# 3          25  1970     AUT       Austria                 mr. kirchschlaeger
# 4          25  1970     BEL       Belgium                         mr. harmel
# ...       ...   ...     ...           ...                                ...
# 7502       70  2015     YEM         Yemen  mr. abdrabuh mansour hadi mansour
# 7503       70  2015     YUG    Yugoslavia               mr. tomislav nikolić
# 7504       70  2015     ZAF  South Africa                         jacob zuma
# 7505       70  2015     ZMB        Zambia             mr. edgar chagwa lungu
# 7506       70  2015     ZWE      Zimbabwe                      robert mugabe
#
#        position                                               text  length
# 0        unkown  33: may i first convey to our president the co...   51419
# 1        unkown  177.\t : it is a fortunate coincidence that pr...   29286
# 2        unkown  100.\t  it is a pleasure for me to extend to y...   31839
# 3        unkown  155.\t  may i begin by expressing to ambassado...   26616
# 4        unkown  176. no doubt each of us, before coming up to ...   25911
# ...         ...                                                ...     ...
# 7502  president  on behalf of the people and the government of ...   10568
# 7503  president  \nseventy years have passed since the establis...   25430
# 7504  president  i should like to congratulate the president an...   13662
# 7505  president  i would like to begin by thanking the secretar...   14247
# 7506  president  allow me at the outset to extend to mr. mogens...   11013
#
# [7507 rows x 8 columns]

# %%
df[df['speaker'].str.contains('bush')]
#displays all the speaker with bush in their name
# Out:
#       session  year country   country_name             speaker   position  \
# 2720       44  1989     USA  United States                bush  president
# 2876       45  1990     USA  United States         george bush     unkown
# 3038       46  1991     USA  United States         george bush  president
# 3207       47  1992     USA  United States     mr. george bush  president
# 4814       56  2001     USA  United States      george w. bush  president
# 5002       57  2002     USA  United States  mr. george w. bush  president
# 5191       58  2003     USA  United States      george w. bush  president
# 5382       59  2004     USA  United States   mr. george w bush  president
# 5760       61  2006     USA  United States  mr. george w. bush  president
# 5951       62  2007     USA  United States      george w. bush  president
# 6143       63  2008     USA  United States      george w. bush  president
#
#                                                    text  length
# 2720  ﻿i am honoured to address the general assembly...   19779
# 2876  ﻿\nit is really a great privilege to greet you...   15843
# 3038  ﻿i am honoured to speak with you as you open t...   15555
# 3207  forty-seven years ago i was a young man of 21,...   21105
# 4814  ﻿we meet in a hall devoted to\npeace; in a cit...   14724
# 5002  ﻿we meet one year and one day\nafter a terrori...   16684
# 5191  ﻿twenty-four months ago, and\nyesterday in the...   16962
# 5382  thank you for the honour of\naddressing the ge...   18628
# 5760  i am grateful for the privilege of \nspeaking ...   16675
# 5951  thank you for the opportunity \nto address the...   15483
# 6143  i am pleased to be here to \naddress the gener...   18384

# %% [markdown]
# # A plot for the length column

# %%
df['length'].plot()
# Out:
# <Axes: >

# %% [markdown]
# # Boxplot

# %%
df['length'].plot(kind='box', vert=False)
# Out:
# <Axes: >

# %% [markdown]
# # Histogram

# %%
df['length'].plot(kind='hist', bins=30)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# # Box plot for lenth and country columns

# %%
import seaborn as sns 
where = df['country'].isin(['USA', 'FRA', 'GBR', 'CHN', 'RUS'])
g = sns.catplot(data=df[where], x="country", y="length", kind='box')
g.fig.set_size_inches(10, 8)
# Out:
# C:\Users\User\anaconda3\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# # REGEX 2¶

# %%
import regex as re# imports the regex

def tokenize(text):
    return re.findall(r'[\w-]*[a-z|A-Z][\w-]*', text)

# %%
testtext = "EE saala cup namde 2024! www.dvd.assam"
testtokens = tokenize(testtext)# tokenizes the given sample
 
print(testtokens)
# Out:
# ['EE', 'saala', 'cup', 'namde', 'www', 'dvd', 'assam']

# %% [markdown]
# # Stopwords

# %%
import nltk 
nltk.download('stopwords')
stopwords = set(nltk.corpus.stopwords.words('english'))
print(stopwords)
# imports the inbuilt stopwords depending upon the language specified
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# {'myself', 'if', 'very', 'or', 'were', 'these', 'as', 'and', 'most', 'her', 't', 'about', 'into', 'when', 'yours', 'wouldn', 'itself', 'for', 'what', 'after', 'hadn', "you've", 'some', 'been', 'whom', 'at', 'have', 'd', 'once', "needn't", 'here', 'while', 'his', 'weren', 'between', 'haven', 'too', 'him', 'be', 'not', 'm', 'that', 'few', 'with', 'own', 'only', "mustn't", 'an', 'them', 'she', 'himself', 'yourselves', 'yourself', 'where', 'themselves', "isn't", 'against', 'can', 'he', 'herself', 'this', "hasn't", 'my', 'so', 'is', 'does', 'having', 'mustn', 'it', 'they', 'up', 'during', 'ma', 'aren', 'from', 'those', 'hasn', 'hers', 'down', 'ourselves', "shouldn't", 'doesn', 'your', 'our', 'again', 'why', 'did', 'to', 'doing', "shan't", 'all', 'over', 'am', 'o', 'being', "you're", 'ours', 'won', 'just', 'because', "couldn't", 'below', 'mightn', 'i', 'no', "you'll", 'in', 'ain', 'the', 'how', 'on', 'couldn', 'of', "mightn't", 'has', 'was', 'any', "haven't", 'should', 'its', "weren't", 'off', 'which', 'both', 'other', "won't", 'more', 'than', "that'll", 'a', 'until', "hadn't", 'me', 'their', 'nor', 'now', 'you', 'by', 'each', 'll', 'had', "didn't", 'through', 'further', "should've", 'didn', 'wasn', 'who', 'we', 'but', "wouldn't", 's', 've', 'same', "wasn't", 'needn', "doesn't", 'isn', 'before', 'will', 'out', "aren't", 'shan', 'do', "it's", 'there', 'shouldn', 'don', 'under', 'above', 're', "you'd", 'are', 'theirs', "she's", 'then', "don't", 'y', 'such'}

# %%
def remove_stop(tokens):
    return [t for t in tokens if t.lower() not in stopwords]
#Just testing it
cleantokens= remove_stop(testtokens)
print(cleantokens)
#removing the stopwords
# Out:
# ['EE', 'saala', 'cup', 'namde', 'www', 'dvd', 'assam']

# %% [markdown]
# # Initialization of the Pipeline

# %%
pipeline = [str.lower, tokenize, remove_stop]

def prepare(text, pipeline):
    tokens = text
    for fun in pipeline:
        tokens = fun(tokens)
    return tokens

# %%
df['tokens'] = df['text'].apply(prepare, pipeline=pipeline)# runs the pipeline

# %% [markdown]
# # Counting the tokens in the dataset

# %%
df['num_tokens'] = df['tokens'].map(len)
df.tail()
# Out:
#       session  year country  country_name                            speaker  \
# 7502       70  2015     YEM         Yemen  mr. abdrabuh mansour hadi mansour
# 7503       70  2015     YUG    Yugoslavia               mr. tomislav nikolić
# 7504       70  2015     ZAF  South Africa                         jacob zuma
# 7505       70  2015     ZMB        Zambia             mr. edgar chagwa lungu
# 7506       70  2015     ZWE      Zimbabwe                      robert mugabe
#
#        position                                               text  length  \
# 7502  president  on behalf of the people and the government of ...   10568
# 7503  president  \nseventy years have passed since the establis...   25430
# 7504  president  i should like to congratulate the president an...   13662
# 7505  president  i would like to begin by thanking the secretar...   14247
# 7506  president  allow me at the outset to extend to mr. mogens...   11013
#
#                                                  tokens  num_tokens
# 7502  [behalf, people, government, yemen, would, lik...         894
# 7503  [seventy, years, passed, since, establishment,...        2118
# 7504  [like, congratulate, president, country, denma...        1160
# 7505  [would, like, begin, thanking, secretary-gener...        1197
# 7506  [allow, outset, extend, mr, mogens, lykketoft,...         903

# %% [markdown]
# # WORD FREQUENCY ANALYSIS
# ## USING THE COUN

# %%
from collections import Counter

tokens = tokenize("She likes my cats and my cats like my sofa.")

testcount= Counter(tokens)
print(testcount)
# testing the counter
# Out:
# Counter({'my': 3, 'cats': 2, 'She': 1, 'likes': 1, 'and': 1, 'like': 1, 'sofa': 1})

# %%
more_tokens = tokenize("She likes dogs and cats.")# adding new data for the already existing count
testcount.update(more_tokens)
print(testcount)
# Out:
# Counter({'my': 3, 'cats': 3, 'She': 2, 'likes': 2, 'and': 2, 'like': 1, 'sofa': 1, 'dogs': 1})

# %%
counter = Counter()
df['tokens'].map(counter.update)# using counter on our dataset
print(counter.most_common(5))
# Out:
# [('nations', 124508), ('united', 120763), ('international', 117223), ('world', 89421), ('countries', 85734)]

# %%
freq_df = pd.DataFrame.from_dict(counter, orient='index', columns=['freq'])
freq_df = freq_df.query('freq >= 1')# specifying the frequency of the word count
freq_df.index.name = 'token'

# %%
freq_df = freq_df.sort_values('freq', ascending=False)
freq_df.head(20)
# sorting the data and displaying it
# Out:
#                  freq
# token
# nations        124508
# united         120763
# international  117223
# world           89421
# countries       85734
# peace           72625
# development     62632
# states          59713
# people          59338
# security        58425
# economic        53833
# must            51880
# also            47403
# new             44453
# country         40878
# assembly        40413
# community       38294
# government      37430
# general         37138
# organization    36434

# %%
freq_df.describe()# stats
# Out:
#                 freq
# count   68302.000000
# mean      162.686276
# std      1544.080072
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%        15.000000
# max    124508.000000

# %% [markdown]
# # BAR CHART FOR TOKEN AND FREQUENCY

# %%
ax = freq_df.head(15).plot(kind='barh', width=0.95, figsize=(12,8))
ax.invert_yaxis()
ax.set(xlabel='Frequency', ylabel='Token', title='Top Words')
# Out:
# [Text(0.5, 0, 'Frequency'), Text(0, 0.5, 'Token'), Text(0.5, 1.0, 'Top Words')]

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Obtaining dependency information for wordcloud from https://files.pythonhosted.org/packages/f5/b0/247159f61c5d5d6647171bef84430b7efad4db504f0229674024f3a4f7f2/wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl.metadata (3.5 kB)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from wordcloud) (1.24.3)
# Requirement already satisfied: pillow in c:\users\user\anaconda3\anaconda\lib\site-packages (from wordcloud) (9.4.0)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\anaconda\lib\site-packages (from wordcloud) (3.7.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\anaconda\lib\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\anaconda\lib\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Downloading wordcloud-1.9.3-cp311-cp311-win_amd64.whl (300 kB)
#    ---------------------------------------- 0.0/300.2 kB ? eta -:--:--
#    - -------------------------------------- 10.2/300.2 kB ? eta -:--:--
#    --- ----------------------------------- 30.7/300.2 kB 435.7 kB/s eta 0:00:01
#    ----------- --------------------------- 92.2/300.2 kB 744.7 kB/s eta 0:00:01
#    ---------------------------------------- 300.2/300.2 kB 1.8 MB/s eta 0:00:00
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # WORD CLOUD

# %%
from wordcloud import WordCloud
from matplotlib import pyplot as plt

text = df.query("year==2015 and country=='USA'")['text'].values[0]

plt.figure(figsize=(14, 7)) ###
wc = WordCloud(max_words=100, stopwords=stopwords)
wc.generate(text)
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
wc = WordCloud(background_color='white', width = 300, height=300, max_words=100, margin=2)
wc.fit_words(freq_df['freq'].to_dict() )
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wc)
plt.axis("off")
plt.tight_layout(pad = 0)
plt.show()
